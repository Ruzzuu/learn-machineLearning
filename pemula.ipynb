# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# Example data
# data = np.array([[10,20,33,44,53,61]])
# data = np.array([[1, 2, 3, 4, 5, 6],
#                  [10, 20, 30, 40, 50, 60],
#                  [5, 15, 25, 35, 45, 55]])
data = np.array([[15],[25],[35],[45],[55],[100000]])


# Min-Max Normalization
min_max = MinMaxScaler()
data_minmax = min_max.fit_transform(data)
print("Min-Max Normalized Data:", data_minmax)

# z-score Standardization
z_scaler = StandardScaler()
data_zscore = z_scaler.fit_transform(data)
print("z-score Standardized Data:", data_zscore)
# Out:
# Min-Max Normalized Data: [[0.00000000e+00]
#  [1.00015002e-04]
#  [2.00030005e-04]
#  [3.00045007e-04]
#  [4.00060009e-04]
#  [1.00000000e+00]]
# z-score Standardized Data: [[-0.44775041]
#  [-0.44748199]
#  [-0.44721357]
#  [-0.44694515]
#  [-0.44667672]
#  [ 2.23606784]]

# %% [markdown]
# now we have big different here, if min max have 0 min and 1 max
